# %%
# %matplotlib inline
import utils; reload(utils)
from utils import *
# Out:
# Using Theano backend.

# %% [markdown]
# ## Setup

# %% [markdown]
# We haven't really looked into the detail of how this works yet - so this is provided for self-study for those who are interested. We'll look at it closely next week.

# %%
path = get_file('nietzsche.txt', origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt")
text = open(path).read()
print('corpus length:', len(text))
# Out:
# ('corpus length:', 600901)

# %%
print(text[:1000])
# Out:
# PREFACE
#
#
# SUPPOSING that Truth is a woman--what then? Is there not ground
# for suspecting that all philosophers, in so far as they have been
# dogmatists, have failed to understand women--that the terrible
# seriousness and clumsy importunity with which they have usually paid
# their addresses to Truth, have been unskilled and unseemly methods for
# winning a woman? Certainly she has never allowed herself to be won; and
# at present every kind of dogma stands with sad and discouraged mien--IF,
# indeed, it stands at all! For there are scoffers who maintain that it
# has fallen, that all dogma lies on the ground--nay more, that it is at
# its last gasp. But to speak seriously, there are good grounds for hoping
# that all dogmatizing in philosophy, whatever solemn, whatever conclusive
# and decided airs it has assumed, may have been only a noble puerilism
# and tyronism; and probably the time is at hand when it will be once
# and again understood WHAT has actually sufficed for the basis of such
# imposing and abso

# %%
chars = sorted(list(set(text)))
vocab_size = len(chars)+1
print('total chars:', vocab_size)
# Out:
# ('total chars:', 86)

# %%
chars.insert(0, "\0")
''.join(chars[1:-6])
# Out:
# '\n !"\'(),-.0123456789:;=?ABCDEFGHIJKLMNOPQRSTUVWXYZ[]_abcdefghijklmnopqrstuvwxyz'

# %%
# interchange mapping char and indices
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# %%
# data to use in the model
idx = [char_indices[c] for c in text]

# %%
''.join(indices_char[i] for i in idx[:70])
# Out:
# 'PREFACE\n\n\nSUPPOSING that Truth is a woman--what then? Is there not gro'

# %% [markdown]
# ## Preprocessing

# %%
# data segmentation to sequences
maxlen = 50
sentences = []
next_chars = []
for i in range(0, len(idx) // maxlen):
    sentences.append(idx[i*maxlen: i*maxlen+maxlen])
    next_chars.append(idx[i*maxlen+1: i*maxlen+maxlen+1])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 12018

# %%
# data segmentation to sequences
maxlen = 50
sentences = []
next_chars = []
for i in range(0, len(idx)-maxlen, maxlen//2):
    sentences.append(idx[i: i+maxlen])
    next_chars.append(idx[i+1: i+maxlen+1])
print('nb sequences:', len(sentences))
# Out:
# ('nb sequences:', 24035)

# %%
print(''.join([indices_char[i] for i in sentences[-1]]))
print(''.join([indices_char[i] for i in next_chars[-1]]))
# Out:
# e
# christian world as the indications of sinfulness
#
# christian world as the indications of sinfulness.

# %%
sentences = np.concatenate([[np.array(o)] for o in sentences])
next_chars = np.concatenate([[np.array(o)] for o in next_chars])

# %%
sentences.shape, next_chars.shape
# Out:
# ((24035, 50), (24035, 50))

# %% [markdown]
# ## Model training

# %%
def sample(probs, temperature):
    """samples an index from a vector of probabilities
    (this is not the most efficient way but is more robust)"""
    # probability distribution with temperature
    prob_temp = np.log(probs) / temperature
    exp_prob = np.exp(prob_temp)
    dist = exp_prob / np.sum(exp_prob)
    choices = range(len(probs))
    return np.random.choice(choices, p=dist)


def generate(temperature=0.75, generated_len=400, seed=0):
    # randomly select a chunk of text
    np.random.seed(seed)
    start_idx = np.random.randint(0, len(idx)-maxlen)
    seed_sent = idx[start_idx: start_idx+maxlen]
    
    sentence = np.array(seed_sent)
    generated = ''.join([indices_char[i] for i in sentence])
    
    while len(generated) < generated_len:
        pred = model.predict(sentence[None, :])[0][-1]
        next_id = sample(pred, temperature)
        generated += indices_char[next_id]
        sentence = np.array(list(sentence[1:]) + [next_id])
    
    return generated

# %%
n_fac = 16

# %%
model=Sequential([
        Embedding(vocab_size, n_fac, input_length=maxlen),
        LSTM(256, return_sequences=True, dropout_U=0.2, dropout_W=0.2),
        Dropout(0.2),
        TimeDistributed(Dense(vocab_size)),
        Activation('softmax')
    ])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam())

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# embedding_1 (Embedding)          (None, 50, 16)        1376        embedding_input_1[0][0]
# ____________________________________________________________________________________________________
# lstm_1 (LSTM)                    (None, 50, 256)       279552      embedding_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 50, 256)       0           lstm_1[0][0]
# ____________________________________________________________________________________________________
# timedistributed_1 (TimeDistribut (None, 50, 86)        22102       dropout_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 50, 86)        0           timedistributed_1[0][0]
# ====================================================================================================
# Total params: 303,030
# Trainable params: 303,030
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
for iteration in range(3):
    print('-' * 50)
    print('Iteration', iteration+1)
    model.fit(sentences, np.expand_dims(next_chars,-1), batch_size=64, nb_epoch=1)
    
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('\n----- diversity:', diversity)
        print(generate(diversity))
    
    print('\n')
# Out:
# --------------------------------------------------
# ('Iteration', 1)
# Epoch 1/1
# 24035/24035 [==============================] - 175s - loss: 2.9428
#
#
# ('----- diversity:', 0.2)
# e puerilism
# and tyronism; and probably the time is the the the the the the the the the the the the an the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the core the the the the the the the the the the the the the the the the the the sore an the the the the the the the the the the the the the the the the the the the the s
#
#
# ('----- diversity:', 0.5)
# ssion for the complex state of delight of the pers whe on thoc the sen tis rarte son in weo pes the and the tiresans on an sound in the ore ferint an the merise af the the an the sust en sons the onos the herel en tha the the the sinsans in of an ins inpas the bond an the d corens and tha the corethore the mocans and cort on anle an the theamfent an the car the tole the conn the heen the sand fhis
#
#
# ('----- diversity:', 1.0)
# without any
# falsification taking place either on thEicall "ficg ond,iNheglo
# d oogis ghay anlta thuphar as av, init of in thar-wiss olneveon tur had isdyewena te hasradros. yh ippisg euds-thind yribeato
# the solge, hre gatidinnindolirecaluniticoon; thas
# citis in whoo w
#  s af oss hatet ond ned, -h an sud tharl hotho, polet, S" taufere bals,, tat hoite ge ertmastine del thilo"-
# e
# mav ll co them sostoa
#
#
# ('----- diversity:', 1.2)
#  of an existence
# side by side of two castes, a hig, ocluthyiy fo klogisor oOesN lode
# nr" ne eresh mes lasalowsifercmit Heat an gt e cfoovesoviuf;
# sromd
# ald ard onfab lun intos to!d meulle, tPho qlEeN
# nag of chae ;rc,-hi coengoogencte
# lonod ant oad ryeon difs, Thes: pal, tine", anet poun ing. meovyEr besd
# bennet
# Fih, nof wwuptile  ar fule th ylird, cact
# enltwory
# - qibien heler trocselt iultto dats,
#
#
# --------------------------------------------------
# ('Iteration', 2)
# Epoch 1/1
# 24035/24035 [==============================] - 176s - loss: 2.4153
#
#
# ('----- diversity:', 0.2)
# y must have
# had, not indeed in regard to his action the somes the preation and the sond the sere the and the precering the sore and the preation the hare of the sore and the herter of the sore the sore the pore of the sere the sount of the sore the some the sere and the rath and sor the were the sore and the some the prencent of the sore and the the the sore the sore the with the sore and the prat
#
#
# ('----- diversity:', 0.5)
# od, her chief concern is appearance and beauty. Le fored the prenention and of be the porititions the goy and where comite hich the moully of and the gare the sorant of it the repent on srilate and mere mome mor the wor the phestand of the orestichest ind and the mand as the ilest and of is the hate of the the serters the han the aster and somstion the srist the penens in the elrered the meve ence
#
#
# ('----- diversity:', 1.0)
# ll estimates, is continually developing, for whate fhe write thich huf
# stimatid, veiniok) bleng--is borenmivatiod ond in hes thithe an incsutice by to risf axend polstipe, WheFasedat of asd boty the cormesis.
# -as at gos the phalcassisatiolucen nort luals,
# and
# id carienes on and
# paraants of the gritertem thre coleg hraw that
# ur imtmap, ol meoverted in home the mowsis sak of puther of ole hathor: t
#
#
# ('----- diversity:', 1.2)
# usness, oppression, and non-freedom;
# it is suspicints, astert: fo exhire muthe
# infeation are Glewert appyill;-Mind poulin; ipass benvego
# o 1ar inoticite luss:
# whe fonctu ivigofond dece,, "vocys fhurlurg exthel "FSE Vthith thos oncret be tlan and saln thite mucduthent es"-KOul'sathed theaopigs ae drijh old tho higile-vebl as thaa thote
# corticise
# to
# a they anpor bacepe fone
# by
# the smpor eWangtis, T
#
#
# --------------------------------------------------
# ('Iteration', 3)
# Epoch 1/1
# 24035/24035 [==============================] - 174s - loss: 2.2343
#
#
# ('----- diversity:', 0.2)
# ts conditions of life, its intrinsic needs. Suppos and the mand and the experity and sore and the porsers of the precher and the some the mast the somest of the rant the selfer and the sourt of the somest to be in the somest of the preation and the sound of the sould the sould and the in the mare of the sound the more and the soment the sound of the man of the soment the sore the sours and in the
#
#
# ('----- diversity:', 0.5)
# the fundamental problems.
#
#
#
# CHAPTER II. THE FREE DORET the and one bestacn and the mave
# in the protely time and pholle is sroune its the sound the ponter and in usting to stink to the somster belision and sither the mave for the somer the will the erestion to
# enouthen and the farse to the conselfs and remsing the pirination be preated to the mave that in the nover and as roct the his wercenter th
#
#
# ('----- diversity:', 1.0)
# ow large, now small. A stone that suddenly
# rolls, cantut pevtuiticatibged on the pining of th ubl.=
# I2 tho been they ca henal, sten momerin and
# trever be
# inepirestuibl there�rests and the
# Fuster to chosh hal SE MU in the the sightire ather, pyptive of thot at a puanm? Geen ponctioss stost and tariat"--und que the ,ce a more and masteft; lon
# (ot hey veverakf
# of gorowert; net,, hith sulls byser. FHE
#
#
# ('----- diversity:', 1.2)
# istophanes!
#
# 29. It is the business of the very fecveatte the bentmn. The festrestiin hipmeled exir rrodozped"t
# in ubluiticimint
# blsig. Whe tumfn om Which. The upnidealitean comptuent to arior of upnuss cennic
# gencal ore
# asberti.wher hitherhg wik; greats!
#  7HTm
#
# E1ASALS"sculay po s of ith atS ach mandust
# mots, the fexert--by efelun, choshe oshfubince of shemer)
# NEVK. I VALFE_. Tuusian. eutucace o

# %% [markdown]
# ### Without embedding

# %%
# one-hot encoding of inputs
trn_inputs = [np.arange(vocab_size)==np.array(sentences[i]).reshape(-1,1) for i in range(len(sentences))]
trn_inputs = np.stack(trn_inputs).astype(np.float32)
trn_targets = [np.arange(vocab_size)==np.array(next_chars[i]).reshape(-1,1) for i in range(len(next_chars))]
trn_targets = np.stack(trn_targets).astype(np.float32)

# %%
trn_inputs.shape, trn_targets.shape
# Out:
# ((24035, 50, 86), (24035, 50, 86))

# %%
def sample(probs, temperature):
    """samples an index from a vector of probabilities
    (this is not the most efficient way but is more robust)"""
    # probability distribution with temperature
    prob_temp = np.log(probs) / temperature
    exp_prob = np.exp(prob_temp)
    dist = exp_prob / np.sum(exp_prob)
    choices = range(len(probs))
    return np.random.choice(choices, p=dist)


def generate(temperature=0.75, generated_len=400, seed=0):
    # randomly select a chunk of text
    np.random.seed(seed)
    start_idx = np.random.randint(0, len(idx)-maxlen)
    seed_sent = idx[start_idx: start_idx+maxlen]

    sentence = np.array(seed_sent)
    generated = ''.join([indices_char[i] for i in sentence])
    
    while len(generated) < generated_len:
        x = (np.arange(vocab_size)==np.array(sentence).reshape(-1,1)).astype(np.float32)
        pred = model.predict(x[None, :])[0][-1]
        next_id = sample(pred, temperature)
        generated += indices_char[next_id]
        sentence = np.array(list(sentence[1:]) + [next_id])
    
    return generated

# %%
model=Sequential([
        LSTM(256, return_sequences=True, dropout_U=0.2, dropout_W=0.2, input_shape=(maxlen, vocab_size)),
        Dropout(0.5),
        TimeDistributed(Dense(vocab_size)),
        Activation('softmax')
    ])

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam())

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lstm_2 (LSTM)                    (None, 50, 256)       351232      lstm_input_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 50, 256)       0           lstm_2[0][0]
# ____________________________________________________________________________________________________
# timedistributed_2 (TimeDistribut (None, 50, 86)        22102       dropout_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 50, 86)        0           timedistributed_2[0][0]
# ====================================================================================================
# Total params: 373,334
# Trainable params: 373,334
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
for iteration in range(3):
    print('-' * 50)
    print('Iteration', iteration+1)
    model.fit(trn_inputs, trn_targets, batch_size=64, nb_epoch=1)
    
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('\n----- diversity:', diversity)
        print(generate(diversity))
    
    print('\n')
# Out:
# --------------------------------------------------
# ('Iteration', 1)
# Epoch 1/1
# 24035/24035 [==============================] - 191s - loss: 2.9269
#
#
# ('----- diversity:', 0.2)
# ession of
# genuine French curiosity and inventive the the the the and the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the to the the sore the the the the the the the the the the here the the the the the the ind and and and and the the the the the the the the the the the the the the and and ind and and and the the the the th
#
#
# ('----- diversity:', 0.5)
# ession of
# genuine French curiosity and inventive the porounithig "oretins of re the there on the meret and man the the whore han in the ans of he ar ther ond unne the the wini in the the the rose tho the the and tor in the there and the the fore ile the and to that eos the wimthe te the tich the cinters ons an the thes at toreresian whe of and touthe se an the the the and some the the in the serti
#
#
# ('----- diversity:', 1.0)
# ession of
# genuine French curiosity and inventive tion rhovergit G tlowles ofseils n pnlwimfibng and iw benancabmails tevever dal, hare nart, ao an t ogivellifuntiis thorhevhen
# ercinaingeopfselutiatey the tool shitvi hida d theth and vhelpeld won: Aigila aointy of
# seipsithidthaus an bhed ot ifecieandtort mmule "urocianwoiugttoot th ifungimat il tuutiice abo
# s ade insgad ehenmanat orlallEB. (o merur
#
#
# ('----- diversity:', 1.2)
# ession of
# genuine French curiosity and inventive tnghenetweriou S totwlis ofthe the
# nlmurediSnhM chehy afe-ge, of ho tawfwis caicea.g] ibitel, cem t ofevenioftforatfritisfurel dnclf enionf.s0atop tmy tem tond pistwo goIg a(s eus ane winjpelcavinac", oic -onety of
# seglsitcoSvievigan and",at idean: intist mly ba urpeo. ys,tavtont"ri hawgeoics le tuvsof ih  o sB PoceitlaE aheis, ar ppreiof an tamdevi
#
#
# --------------------------------------------------
# ('Iteration', 2)
# Epoch 1/1
# 24035/24035 [==============================] - 173s - loss: 2.5010
#
#
# ('----- diversity:', 0.2)
# ession of
# genuine French curiosity and inventive the pores in the the the the sere and the sere the stere the and and and the and and and the sere the the sont some the the somen the sore the the the the the and the presting of the mont of the sere the and the selle the mont and and and the and and the and and the serting the the and sore the and the seres in the sore of the perest of the and and
#
#
# ('----- diversity:', 0.5)
# ession of
# genuine French curiosity and inventive the mentong st all to the bore the sorthe the dand nt and mance for thish the hand the anpercing an the fore the hinkeratend the heramen the mestily weras the arentus in the ther and atand he dore in sonca tios, that mesting the sell congers in the netist of mal the rartins to the randing in mencitutind an the alle the ale sore fond the gens the pre
#
#
# ('----- diversity:', 1.0)
# ession of
# genuine French curiosity and inventive toed pituls ms a.. Wusde sathe the
# orktle, The andely bele, ain chodm whuri galaed pomicited sear t okgt non whor thiss, lxonh himinceasecofregsor tizat of the rertyl goan casceto blifureas in wioh Chere I, insward
# selnsouls wilus biag--fert lasd bed vist now ed
# ursen lypeuktuskofas
# dawion as jf tuuth, hac rata arally cabiferilico ppreisald Sr mcove
#
#
# ('----- diversity:', 1.2)
# ession of
# genuine French curiosity and inventive toinegaty soou,
#
# sprysis ofreecs, ,arhurd paroe fhecy bench.
# "W7--pat whwis
# GNMAGF decicly of eer t oist noo,ectigratitneby, oB ogke eorelnct itis urzat ofDrhe sistyp hoch casceus and wione hadslif- herd AEd, ty re selnsitel,; avilam chemant lased andsroucinw, a vfren kxtevetusns th iewher.
# Y ha tuvrpe il Fo sabcielerob;
# alehilg s5otlall fde tambly"
#
#
# --------------------------------------------------
# ('Iteration', 3)
# Epoch 1/1
# 24035/24035 [==============================] - 187s - loss: 2.3627
#
#
# ('----- diversity:', 0.2)
# ession of
# genuine French curiosity and inventive the prestion the sore the is and the sore the mand the mand and and the with the perest of the hand the mane the mant the with the recerse the sore to the sore the wich the and the sont of the the for the and the mand the mant of the mand the here the sore the canting of the the mens and the man the some the sele the sele the mant of the man the sor
#
#
# ('----- diversity:', 0.5)
# ession of
# genuine French curiosity and inventive the menting of cartition of the meat on the recelises and ned peres the with and mane sentare in ar of the perition the sour the gore the rether the wat of the sirstice and ard that sestering as in and in and to the has on the dose sall sent of the mation of the with and it to the panct of hing astition and arcall, stom and the compring in the mant
#
#
# ('----- diversity:', 1.0)
# ession of
# genuine French curiosity and inventive to pirity thes a touth, ancupils, Boreting,
# prebeerey beferad of is thodsar dalage soin prepere oda perveriont ther thith whel
# arddad, ond it itll tizat of the pirtus hn pal seitialions not haks--an inef acphity of
# the soulo us us coake, coude sind lfussr oms caatise,
# ivneulyeres th o whire the atwrusc in ar
# sacciines, abe more bo proing, an the mur
#
#
# ('----- diversity:', 1.2)
# ession of
# genuine French curiosity and inventive to ngomsuls, wab tosusen oflimding
# ondtmens on alebiw' ar. DE2R DGe sOwever
# baice Wnecicited seco t mcoveliogs ties thith,: hiN of ig, nos, thesel vizat), tne Jonmswo goda.
# ralvg and wiond hafsjoed
# fhim.
#
# heaty of
# the, ouln wigs--an and ditanas. AEPEoppraonve TAris1c! woludstops th may lokat mactuutilad aar
# saccledbyce Seanlo, as
# ospelnalal tcedeve
